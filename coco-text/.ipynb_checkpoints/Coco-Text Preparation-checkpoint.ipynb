# %%
import coco_text
COCO_DATA='/home/sravya/data/muse/coco/coco2014/'
ct = coco_text.COCO_Text(COCO_DATA+ 'COCO_Text.json')
# Out:
# loading annotations into memory...
# 0:00:01.455737
# creating index...
# index created!

# %%
import tensorflow as tf
from tqdm import tqdm
from PIL import Image

import sys
sys.path.append("/home/sravya/git/models")
from object_detection.utils import dataset_util

def writeTF(ImgIds, dataType, out_path):
    skipped_boxes = 0
    size_mismatch = 0
    empty_images = 0
    skipped_files = 0

    path = '{}{}/'.format(COCO_DATA, dataType)
    writer = tf.python_io.TFRecordWriter(out_path)

    for imgId in tqdm(ImgIds):
        img = ct.loadImgs(imgId)[0]
        filename = img['file_name']
        pil_img = Image.open(path + filename)
        width, height = pil_img.size

        #Sanity check
        if(width != img['width'] or height != img['height']):
            size_mismatch += 1
            width = img['width']
            height = img['height']    

        #Sanity check
        if(height == 0 or width == 0):
            empty_images += 1
            continue

        annIds = ct.getAnnIds(imgId)
        anns = ct.loadAnns(annIds)

        xmins = []
        ymins = []
        xmaxs = []
        ymaxs = []
        classes_text = [] # List of string class name of bounding box (1 per box)
        classes = []

        for ann in anns:
            xmin = ann['bbox'][0]
            ymin = ann['bbox'][1]
            b_width = ann['bbox'][2]
            b_height = ann['bbox'][3]
            xmax = xmin + b_width
            ymax = ymin + b_height

            #Normalize
            xmin = xmin/width
            xmax = xmax/width
            ymin = ymin/height
            ymax = ymax/height

            if(xmin<1 and ymin<1 and xmax<1 and ymax<1):
                xmins.append(xmin)
                ymins.append(ymin)
                xmaxs.append(xmax)
                ymaxs.append(ymax)
                classes_text.append('Text'.encode('utf8'))
                classes.append(1)
            else:
                skipped_boxes +=1

        with tf.gfile.GFile((path + filename), 'rb') as fid:
            encoded_image_data = fid.read()
        filename = path + filename
        filename = filename.encode('utf8')
        image_format = b'jpg'

        if (len(xmins) != 0):
            tf_example = tf.train.Example(features=tf.train.Features(feature={
            'image/height': dataset_util.int64_feature(height),
            'image/width': dataset_util.int64_feature(width),
            'image/filename': dataset_util.bytes_feature(filename),
            'image/source_id': dataset_util.bytes_feature(filename),
            'image/encoded': dataset_util.bytes_feature(encoded_image_data),
            'image/format': dataset_util.bytes_feature(image_format),
            'image/object/bbox/xmin': dataset_util.float_list_feature(xmins),
            'image/object/bbox/xmax': dataset_util.float_list_feature(xmaxs),
            'image/object/bbox/ymin': dataset_util.float_list_feature(ymins),
            'image/object/bbox/ymax': dataset_util.float_list_feature(ymaxs),
            'image/object/class/text': dataset_util.bytes_list_feature(classes_text),
            'image/object/class/label': dataset_util.int64_list_feature(classes),
            }))
            writer.write(tf_example.SerializeToString())        
        else:
            skipped_files += 1
    print('skipped_boxes:{} size_mismatch: {} empty_images: {} skipped_files: {}'.format(
        skipped_boxes, size_mismatch, empty_images, skipped_files))

# %%
training_record = '/home/sravya/data/muse/coco/coco2014/TF/training.record'
train_dir='train2014'
valid_record = '/home/sravya/data/muse/coco/coco2014/TF/valid.record'
#val_dir='val2014'

train_img_ids = ct.getImgIds(imgIds=ct.train, catIds=[('legibility','legible')])
valid_img_ids = ct.getImgIds(imgIds=ct.val, catIds=[('legibility','legible')])

# %%
writeTF(train_img_ids, train_dir, training_record)
writeTF(valid_img_ids, train_dir, valid_record)
# Out:
# 100%|██████████| 15124/15124 [00:06<00:00, 2373.63it/s]
#   7%|▋         | 230/3522 [00:00<00:01, 2298.19it/s]
# skipped_boxes:0 size_mismatch: 0 empty_images: 0 skipped_files: 0
# 100%|██████████| 3522/3522 [00:01<00:00, 2413.09it/s]
# skipped_boxes:0 size_mismatch: 0 empty_images: 0 skipped_files: 0

# %%
# Check x, y
img_id = train_img_ids[456]
img = ct.loadImgs(img_id)
path = '{}{}/'.format(COCO_DATA, 'train2014')    
filename = img[0]['file_name']
ann_ids = ct.getAnnIds(img_id)
anns = ct.loadAnns(ann_ids)
anns[0]['bbox'][0], anns[0]['bbox'][1]
# Out:
# (237.35902881622314, 256.32779026031494)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
plt.figure()
plt.imshow(Image.open(path + filename))
xmin = anns[1]['bbox'][0]
ymax = anns[1]['bbox'][1]
b_width = anns[1]['bbox'][2]
b_height = anns[1]['bbox'][3]
xmax = xmin + b_width
ymin = ymax + b_height
xs = [xmin, xmax]
ys = [ymax, ymin]
vcol = ['r','g']
for j in [0,1]:
    plt.scatter(xs[j],ys[j], color=vcol[j])

# %%
b_width,b_height
# Out:
# (38, 19)

# %%
path = '{}{}/'.format(COCO_DATA, 'train2014')    
filename = 'COCO_train2014_000000032778.jpg'
img = Image.open(path + filename)
img

# %%
set(train_img_ids).intersection(valid_img_ids)
# Out:
# set()

# %%
len(valid_img_ids)
# Out:
# 3522

# %%
len(ct.train)
# Out:
# 43686

# %%
imgIds = ct.getImgIds(imgIds=ct.train)

# %%
len(imgIds)
# Out:
# 43686

# %%
writeTF(imgIds, dataType, out_path)
# Out:
# 100%|██████████| 10000/10000 [00:22<00:00, 444.16it/s]
# skipped_boxes:0 size_mismatch: 0 empty_images: 0 skipped_files: 4922

# %%
len(imgIds)
# Out:
# 10000

# %%
imgs = ct.loadImgs(imgIds)

# %%
val_imgs = []
for img in imgs:
    if( 'train' in img['file_name']):
        val_imgs.append(img)

# %%
len(val_imgs)
# Out:
# 10000

# %%
ImgIds = ct.getImgIds(imgIds=ct.train, 
                    catIds=[('legibility','legible')])
for imgId in tqdm(ImgIds):
    ct.loadImgs(imgId)

# %%
imgs = ct.loadImgs(imgIds)

# %%
len(imgs)
# Out:
# 10000

# %%
imgs
# Out:
# [{'file_name': 'COCO_train2014_000000229378.jpg',
#   'height': 640,
#   'id': 229378,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000524291.jpg',
#   'height': 426,
#   'id': 524291,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000491525.jpg',
#   'height': 480,
#   'id': 491525,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000393223.jpg',
#   'height': 480,
#   'id': 393223,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000294925.jpg',
#   'height': 480,
#   'id': 294925,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000163866.jpg',
#   'height': 265,
#   'id': 163866,
#   'set': 'val',
#   'width': 320},
#  {'file_name': 'COCO_train2014_000000262172.jpg',
#   'height': 480,
#   'id': 262172,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000032804.jpg',
#   'height': 358,
#   'id': 32804,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000000036.jpg',
#   'height': 640,
#   'id': 36,
#   'set': 'val',
#   'width': 481},
#  {'file_name': 'COCO_train2014_000000524331.jpg',
#   'height': 640,
#   'id': 524331,
#   'set': 'val',
#   'width': 406},
#  {'file_name': 'COCO_train2014_000000032819.jpg',
#   'height': 425,
#   'id': 32819,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000458804.jpg',
#   'height': 640,
#   'id': 458804,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000393268.jpg',
#   'height': 480,
#   'id': 393268,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000196663.jpg',
#   'height': 480,
#   'id': 196663,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000000061.jpg',
#   'height': 488,
#   'id': 61,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000557118.jpg',
#   'height': 427,
#   'id': 557118,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000491581.jpg',
#   'height': 426,
#   'id': 491581,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000000064.jpg',
#   'height': 640,
#   'id': 64,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000196675.jpg',
#   'height': 359,
#   'id': 196675,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000229449.jpg',
#   'height': 427,
#   'id': 229449,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000065612.jpg',
#   'height': 640,
#   'id': 65612,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000491597.jpg',
#   'height': 480,
#   'id': 491597,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000000077.jpg',
#   'height': 375,
#   'id': 77,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000000078.jpg',
#   'height': 612,
#   'id': 78,
#   'set': 'val',
#   'width': 612},
#  {'file_name': 'COCO_train2014_000000393292.jpg',
#   'height': 480,
#   'id': 393292,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000393297.jpg',
#   'height': 612,
#   'id': 393297,
#   'set': 'val',
#   'width': 612},
#  {'file_name': 'COCO_train2014_000000196691.jpg',
#   'height': 612,
#   'id': 196691,
#   'set': 'val',
#   'width': 612},
#  {'file_name': 'COCO_train2014_000000327766.jpg',
#   'height': 333,
#   'id': 327766,
#   'set': 'val',
#   'width': 250},
#  {'file_name': 'COCO_train2014_000000131160.jpg',
#   'height': 427,
#   'id': 131160,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000360536.jpg',
#   'height': 480,
#   'id': 360536,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000557151.jpg',
#   'height': 427,
#   'id': 557151,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000262239.jpg',
#   'height': 426,
#   'id': 262239,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000557155.jpg',
#   'height': 382,
#   'id': 557155,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000131172.jpg',
#   'height': 469,
#   'id': 131172,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000426086.jpg',
#   'height': 640,
#   'id': 426086,
#   'set': 'val',
#   'width': 478},
#  {'file_name': 'COCO_train2014_000000458856.jpg',
#   'height': 427,
#   'id': 458856,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000065643.jpg',
#   'height': 425,
#   'id': 65643,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000426094.jpg',
#   'height': 478,
#   'id': 426094,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000524401.jpg',
#   'height': 427,
#   'id': 524401,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000458876.jpg',
#   'height': 474,
#   'id': 458876,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000196748.jpg',
#   'height': 480,
#   'id': 196748,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000000144.jpg',
#   'height': 480,
#   'id': 144,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000491666.jpg',
#   'height': 427,
#   'id': 491666,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000229525.jpg',
#   'height': 424,
#   'id': 229525,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000426143.jpg',
#   'height': 334,
#   'id': 426143,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000327841.jpg',
#   'height': 480,
#   'id': 327841,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000557219.jpg',
#   'height': 461,
#   'id': 557219,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000491684.jpg',
#   'height': 612,
#   'id': 491684,
#   'set': 'val',
#   'width': 612},
#  {'file_name': 'COCO_train2014_000000426151.jpg',
#   'height': 443,
#   'id': 426151,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000196776.jpg',
#   'height': 640,
#   'id': 196776,
#   'set': 'val',
#   'width': 424},
#  {'file_name': 'COCO_train2014_000000458922.jpg',
#   'height': 427,
#   'id': 458922,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000098478.jpg',
#   'height': 640,
#   'id': 98478,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000458931.jpg',
#   'height': 487,
#   'id': 458931,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000327860.jpg',
#   'height': 480,
#   'id': 327860,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000360630.jpg',
#   'height': 427,
#   'id': 360630,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000393403.jpg',
#   'height': 480,
#   'id': 393403,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000098494.jpg',
#   'height': 480,
#   'id': 98494,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000164036.jpg',
#   'height': 640,
#   'id': 164036,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000196804.jpg',
#   'height': 320,
#   'id': 196804,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000032967.jpg',
#   'height': 426,
#   'id': 32967,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000164041.jpg',
#   'height': 371,
#   'id': 164041,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000164042.jpg',
#   'height': 427,
#   'id': 164042,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000458955.jpg',
#   'height': 377,
#   'id': 458955,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000164044.jpg',
#   'height': 480,
#   'id': 164044,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000491727.jpg',
#   'height': 360,
#   'id': 491727,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000426191.jpg',
#   'height': 640,
#   'id': 426191,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000295122.jpg',
#   'height': 640,
#   'id': 295122,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000491736.jpg',
#   'height': 427,
#   'id': 491736,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000491739.jpg',
#   'height': 428,
#   'id': 491739,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000426204.jpg',
#   'height': 375,
#   'id': 426204,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000098529.jpg',
#   'height': 332,
#   'id': 98529,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000164066.jpg',
#   'height': 640,
#   'id': 164066,
#   'set': 'val',
#   'width': 426},
#  {'file_name': 'COCO_train2014_000000131300.jpg',
#   'height': 500,
#   'id': 131300,
#   'set': 'val',
#   'width': 335},
#  {'file_name': 'COCO_train2014_000000524518.jpg',
#   'height': 640,
#   'id': 524518,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000491753.jpg',
#   'height': 480,
#   'id': 491753,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000557291.jpg',
#   'height': 427,
#   'id': 557291,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000524525.jpg',
#   'height': 640,
#   'id': 524525,
#   'set': 'val',
#   'width': 453},
#  {'file_name': 'COCO_train2014_000000033009.jpg',
#   'height': 640,
#   'id': 33009,
#   'set': 'val',
#   'width': 426},
#  {'file_name': 'COCO_train2014_000000131315.jpg',
#   'height': 427,
#   'id': 131315,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000459000.jpg',
#   'height': 456,
#   'id': 459000,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000557308.jpg',
#   'height': 360,
#   'id': 557308,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000098563.jpg',
#   'height': 640,
#   'id': 98563,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000262407.jpg',
#   'height': 640,
#   'id': 262407,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000131339.jpg',
#   'height': 427,
#   'id': 131339,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000393487.jpg',
#   'height': 263,
#   'id': 393487,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000360719.jpg',
#   'height': 433,
#   'id': 360719,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000033042.jpg',
#   'height': 444,
#   'id': 33042,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000164114.jpg',
#   'height': 375,
#   'id': 164114,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000295193.jpg',
#   'height': 338,
#   'id': 295193,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000557342.jpg',
#   'height': 423,
#   'id': 557342,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000557344.jpg',
#   'height': 319,
#   'id': 557344,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000098592.jpg',
#   'height': 612,
#   'id': 98592,
#   'set': 'val',
#   'width': 612},
#  {'file_name': 'COCO_train2014_000000360739.jpg',
#   'height': 427,
#   'id': 360739,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000131366.jpg',
#   'height': 509,
#   'id': 131366,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000131374.jpg',
#   'height': 294,
#   'id': 131374,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000491826.jpg',
#   'height': 375,
#   'id': 491826,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000000308.jpg',
#   'height': 426,
#   'id': 308,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000000312.jpg',
#   'height': 427,
#   'id': 312,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000360760.jpg',
#   'height': 334,
#   'id': 360760,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000262463.jpg',
#   'height': 458,
#   'id': 262463,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000295236.jpg',
#   'height': 359,
#   'id': 295236,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000098629.jpg',
#   'height': 640,
#   'id': 98629,
#   'set': 'val',
#   'width': 449},
#  {'file_name': 'COCO_train2014_000000524613.jpg',
#   'height': 154,
#   'id': 524613,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000000326.jpg',
#   'height': 427,
#   'id': 326,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000164168.jpg',
#   'height': 348,
#   'id': 164168,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000295245.jpg',
#   'height': 500,
#   'id': 295245,
#   'set': 'val',
#   'width': 335},
#  {'file_name': 'COCO_train2014_000000524623.jpg',
#   'height': 640,
#   'id': 524623,
#   'set': 'val',
#   'width': 481},
#  {'file_name': 'COCO_train2014_000000459093.jpg',
#   'height': 427,
#   'id': 459093,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000328036.jpg',
#   'height': 405,
#   'id': 328036,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000065898.jpg',
#   'height': 427,
#   'id': 65898,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000164205.jpg',
#   'height': 456,
#   'id': 164205,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000164211.jpg',
#   'height': 640,
#   'id': 164211,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000524662.jpg',
#   'height': 480,
#   'id': 524662,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000164222.jpg',
#   'height': 640,
#   'id': 164222,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000393601.jpg',
#   'height': 640,
#   'id': 393601,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000098693.jpg',
#   'height': 640,
#   'id': 98693,
#   'set': 'val',
#   'width': 426},
#  {'file_name': 'COCO_train2014_000000524679.jpg',
#   'height': 419,
#   'id': 524679,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000000394.jpg',
#   'height': 611,
#   'id': 394,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000524692.jpg',
#   'height': 427,
#   'id': 524692,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000065943.jpg',
#   'height': 425,
#   'id': 65943,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000459166.jpg',
#   'height': 427,
#   'id': 459166,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000295329.jpg',
#   'height': 480,
#   'id': 295329,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000033186.jpg',
#   'height': 640,
#   'id': 33186,
#   'set': 'val',
#   'width': 482},
#  {'file_name': 'COCO_train2014_000000360869.jpg',
#   'height': 400,
#   'id': 360869,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000393638.jpg',
#   'height': 640,
#   'id': 393638,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000557483.jpg',
#   'height': 375,
#   'id': 557483,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000098733.jpg',
#   'height': 374,
#   'id': 98733,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000524723.jpg',
#   'height': 480,
#   'id': 524723,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000131511.jpg',
#   'height': 427,
#   'id': 131511,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000098746.jpg',
#   'height': 416,
#   'id': 98746,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000098748.jpg',
#   'height': 375,
#   'id': 98748,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000262588.jpg',
#   'height': 480,
#   'id': 262588,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000164286.jpg',
#   'height': 480,
#   'id': 164286,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000098752.jpg',
#   'height': 427,
#   'id': 98752,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000360898.jpg',
#   'height': 480,
#   'id': 360898,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000098760.jpg',
#   'height': 427,
#   'id': 98760,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000131534.jpg',
#   'height': 480,
#   'id': 131534,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000197071.jpg',
#   'height': 480,
#   'id': 197071,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000459214.jpg',
#   'height': 428,
#   'id': 459214,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000459218.jpg',
#   'height': 500,
#   'id': 459218,
#   'set': 'val',
#   'width': 378},
#  {'file_name': 'COCO_train2014_000000393686.jpg',
#   'height': 425,
#   'id': 393686,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000229856.jpg',
#   'height': 427,
#   'id': 229856,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000328163.jpg',
#   'height': 360,
#   'id': 328163,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000197091.jpg',
#   'height': 640,
#   'id': 197091,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000393705.jpg',
#   'height': 480,
#   'id': 393705,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000426474.jpg',
#   'height': 478,
#   'id': 426474,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000393707.jpg',
#   'height': 640,
#   'id': 393707,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000131564.jpg',
#   'height': 640,
#   'id': 131564,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000524786.jpg',
#   'height': 480,
#   'id': 524786,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000131572.jpg',
#   'height': 480,
#   'id': 131572,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000164348.jpg',
#   'height': 399,
#   'id': 164348,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000131580.jpg',
#   'height': 640,
#   'id': 131580,
#   'set': 'val',
#   'width': 424},
#  {'file_name': 'COCO_train2014_000000000510.jpg',
#   'height': 480,
#   'id': 510,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000524802.jpg',
#   'height': 240,
#   'id': 524802,
#   'set': 'val',
#   'width': 320},
#  {'file_name': 'COCO_train2014_000000262662.jpg',
#   'height': 480,
#   'id': 262662,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000393735.jpg',
#   'height': 640,
#   'id': 393735,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000295443.jpg',
#   'height': 480,
#   'id': 295443,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000033303.jpg',
#   'height': 640,
#   'id': 33303,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000426519.jpg',
#   'height': 522,
#   'id': 426519,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000262683.jpg',
#   'height': 640,
#   'id': 262683,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000000542.jpg',
#   'height': 484,
#   'id': 542,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000295455.jpg',
#   'height': 426,
#   'id': 295455,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000328223.jpg',
#   'height': 480,
#   'id': 328223,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000492065.jpg',
#   'height': 640,
#   'id': 492065,
#   'set': 'val',
#   'width': 425},
#  {'file_name': 'COCO_train2014_000000033315.jpg',
#   'height': 428,
#   'id': 33315,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000262692.jpg',
#   'height': 333,
#   'id': 262692,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000328228.jpg',
#   'height': 480,
#   'id': 328228,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000066096.jpg',
#   'height': 640,
#   'id': 66096,
#   'set': 'val',
#   'width': 433},
#  {'file_name': 'COCO_train2014_000000459319.jpg',
#   'height': 480,
#   'id': 459319,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000557628.jpg',
#   'height': 480,
#   'id': 557628,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000033341.jpg',
#   'height': 424,
#   'id': 33341,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000033352.jpg',
#   'height': 394,
#   'id': 33352,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000033358.jpg',
#   'height': 500,
#   'id': 33358,
#   'set': 'val',
#   'width': 375},
#  {'file_name': 'COCO_train2014_000000361038.jpg',
#   'height': 640,
#   'id': 361038,
#   'set': 'val',
#   'width': 426},
#  {'file_name': 'COCO_train2014_000000328270.jpg',
#   'height': 640,
#   'id': 328270,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000197201.jpg',
#   'height': 400,
#   'id': 197201,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000098903.jpg',
#   'height': 428,
#   'id': 98903,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000459354.jpg',
#   'height': 640,
#   'id': 459354,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000492125.jpg',
#   'height': 414,
#   'id': 492125,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000361054.jpg',
#   'height': 427,
#   'id': 361054,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000426591.jpg',
#   'height': 480,
#   'id': 426591,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000524897.jpg',
#   'height': 640,
#   'id': 524897,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000066151.jpg',
#   'height': 480,
#   'id': 66151,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000459372.jpg',
#   'height': 426,
#   'id': 459372,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000000625.jpg',
#   'height': 446,
#   'id': 625,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000131697.jpg',
#   'height': 480,
#   'id': 131697,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000524916.jpg',
#   'height': 640,
#   'id': 524916,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000230005.jpg',
#   'height': 413,
#   'id': 230005,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000492154.jpg',
#   'height': 410,
#   'id': 492154,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000524925.jpg',
#   'height': 441,
#   'id': 524925,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000328318.jpg',
#   'height': 640,
#   'id': 328318,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000557694.jpg',
#   'height': 461,
#   'id': 557694,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000361088.jpg',
#   'height': 442,
#   'id': 361088,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000524929.jpg',
#   'height': 640,
#   'id': 524929,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000000643.jpg',
#   'height': 375,
#   'id': 643,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000098950.jpg',
#   'height': 425,
#   'id': 98950,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000524935.jpg',
#   'height': 480,
#   'id': 524935,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000033416.jpg',
#   'height': 480,
#   'id': 33416,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000393867.jpg',
#   'height': 480,
#   'id': 393867,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000492171.jpg',
#   'height': 427,
#   'id': 492171,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000426642.jpg',
#   'height': 536,
#   'id': 426642,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000492179.jpg',
#   'height': 427,
#   'id': 492179,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000164502.jpg',
#   'height': 640,
#   'id': 164502,
#   'set': 'val',
#   'width': 438},
#  {'file_name': 'COCO_train2014_000000197270.jpg',
#   'height': 379,
#   'id': 197270,
#   'set': 'val',
#   'width': 608},
#  {'file_name': 'COCO_train2014_000000230039.jpg',
#   'height': 427,
#   'id': 230039,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000000671.jpg',
#   'height': 427,
#   'id': 671,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000000673.jpg',
#   'height': 481,
#   'id': 673,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000361136.jpg',
#   'height': 612,
#   'id': 361136,
#   'set': 'val',
#   'width': 612},
#  {'file_name': 'COCO_train2014_000000131763.jpg',
#   'height': 480,
#   'id': 131763,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000492214.jpg',
#   'height': 480,
#   'id': 492214,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000492215.jpg',
#   'height': 640,
#   'id': 492215,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000524984.jpg',
#   'height': 430,
#   'id': 524984,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000197305.jpg',
#   'height': 480,
#   'id': 197305,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000066236.jpg',
#   'height': 427,
#   'id': 66236,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000033471.jpg',
#   'height': 480,
#   'id': 33471,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000295620.jpg',
#   'height': 640,
#   'id': 295620,
#   'set': 'val',
#   'width': 477},
#  {'file_name': 'COCO_train2014_000000295626.jpg',
#   'height': 334,
#   'id': 295626,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000262862.jpg',
#   'height': 426,
#   'id': 262862,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000197329.jpg',
#   'height': 427,
#   'id': 197329,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000099040.jpg',
#   'height': 426,
#   'id': 99040,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000557794.jpg',
#   'height': 640,
#   'id': 557794,
#   'set': 'val',
#   'width': 425},
#  {'file_name': 'COCO_train2014_000000426728.jpg',
#   'height': 425,
#   'id': 426728,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000131816.jpg',
#   'height': 612,
#   'id': 131816,
#   'set': 'val',
#   'width': 612},
#  {'file_name': 'COCO_train2014_000000131826.jpg',
#   'height': 375,
#   'id': 131826,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000361208.jpg',
#   'height': 425,
#   'id': 361208,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000197368.jpg',
#   'height': 640,
#   'id': 197368,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000459524.jpg',
#   'height': 500,
#   'id': 459524,
#   'set': 'val',
#   'width': 333},
#  {'file_name': 'COCO_train2014_000000492292.jpg',
#   'height': 480,
#   'id': 492292,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000361222.jpg',
#   'height': 640,
#   'id': 361222,
#   'set': 'val',
#   'width': 507},
#  {'file_name': 'COCO_train2014_000000197384.jpg',
#   'height': 458,
#   'id': 197384,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000099086.jpg',
#   'height': 480,
#   'id': 99086,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000230160.jpg',
#   'height': 478,
#   'id': 230160,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000033555.jpg',
#   'height': 640,
#   'id': 33555,
#   'set': 'val',
#   'width': 428},
#  {'file_name': 'COCO_train2014_000000230164.jpg',
#   'height': 480,
#   'id': 230164,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000426773.jpg',
#   'height': 360,
#   'id': 426773,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000066327.jpg',
#   'height': 480,
#   'id': 66327,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000230168.jpg',
#   'height': 333,
#   'id': 230168,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000197401.jpg',
#   'height': 480,
#   'id': 197401,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000164638.jpg',
#   'height': 640,
#   'id': 164638,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000361246.jpg',
#   'height': 401,
#   'id': 361246,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000557860.jpg',
#   'height': 480,
#   'id': 557860,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000426791.jpg',
#   'height': 480,
#   'id': 426791,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000262954.jpg',
#   'height': 427,
#   'id': 262954,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000525101.jpg',
#   'height': 640,
#   'id': 525101,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000262962.jpg',
#   'height': 428,
#   'id': 262962,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000164659.jpg',
#   'height': 640,
#   'id': 164659,
#   'set': 'val',
#   'width': 465},
#  {'file_name': 'COCO_train2014_000000000821.jpg',
#   'height': 640,
#   'id': 821,
#   'set': 'val',
#   'width': 512},
#  {'file_name': 'COCO_train2014_000000033593.jpg',
#   'height': 427,
#   'id': 33593,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000492354.jpg',
#   'height': 480,
#   'id': 492354,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000295748.jpg',
#   'height': 480,
#   'id': 295748,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000066381.jpg',
#   'height': 268,
#   'id': 66381,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000262991.jpg',
#   'height': 427,
#   'id': 262991,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000230224.jpg',
#   'height': 480,
#   'id': 230224,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000394071.jpg',
#   'height': 640,
#   'id': 394071,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000230236.jpg',
#   'height': 640,
#   'id': 230236,
#   'set': 'val',
#   'width': 478},
#  {'file_name': 'COCO_train2014_000000263006.jpg',
#   'height': 428,
#   'id': 263006,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000263008.jpg',
#   'height': 427,
#   'id': 263008,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000525153.jpg',
#   'height': 499,
#   'id': 525153,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000426850.jpg',
#   'height': 640,
#   'id': 426850,
#   'set': 'val',
#   'width': 620},
#  {'file_name': 'COCO_train2014_000000099170.jpg',
#   'height': 445,
#   'id': 99170,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000230246.jpg',
#   'height': 500,
#   'id': 230246,
#   'set': 'val',
#   'width': 375},
#  {'file_name': 'COCO_train2014_000000557931.jpg',
#   'height': 640,
#   'id': 557931,
#   'set': 'val',
#   'width': 425},
#  {'file_name': 'COCO_train2014_000000394100.jpg',
#   'height': 640,
#   'id': 394100,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000426869.jpg',
#   'height': 480,
#   'id': 426869,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000361334.jpg',
#   'height': 480,
#   'id': 361334,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000263036.jpg',
#   'height': 640,
#   'id': 263036,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000426880.jpg',
#   'height': 429,
#   'id': 426880,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000099211.jpg',
#   'height': 427,
#   'id': 99211,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000066443.jpg',
#   'height': 426,
#   'id': 66443,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000099222.jpg',
#   'height': 375,
#   'id': 99222,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000459673.jpg',
#   'height': 425,
#   'id': 459673,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000361373.jpg',
#   'height': 640,
#   'id': 361373,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000000927.jpg',
#   'height': 612,
#   'id': 927,
#   'set': 'val',
#   'width': 612},
#  {'file_name': 'COCO_train2014_000000033695.jpg',
#   'height': 481,
#   'id': 33695,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000295840.jpg',
#   'height': 640,
#   'id': 295840,
#   'set': 'val',
#   'width': 360},
#  {'file_name': 'COCO_train2014_000000066466.jpg',
#   'height': 480,
#   'id': 66466,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000164772.jpg',
#   'height': 480,
#   'id': 164772,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000361389.jpg',
#   'height': 640,
#   'id': 361389,
#   'set': 'val',
#   'width': 426},
#  {'file_name': 'COCO_train2014_000000230318.jpg',
#   'height': 424,
#   'id': 230318,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000394165.jpg',
#   'height': 480,
#   'id': 394165,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000263094.jpg',
#   'height': 640,
#   'id': 263094,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000558011.jpg',
#   'height': 500,
#   'id': 558011,
#   'set': 'val',
#   'width': 333},
#  {'file_name': 'COCO_train2014_000000230334.jpg',
#   'height': 480,
#   'id': 230334,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000033727.jpg',
#   'height': 427,
#   'id': 33727,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000197570.jpg',
#   'height': 500,
#   'id': 197570,
#   'set': 'val',
#   'width': 332},
#  {'file_name': 'COCO_train2014_000000459716.jpg',
#   'height': 480,
#   'id': 459716,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000033733.jpg',
#   'height': 480,
#   'id': 33733,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000066503.jpg',
#   'height': 449,
#   'id': 66503,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000361428.jpg',
#   'height': 427,
#   'id': 361428,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000295893.jpg',
#   'height': 640,
#   'id': 295893,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000033751.jpg',
#   'height': 640,
#   'id': 33751,
#   'set': 'val',
#   'width': 478},
#  {'file_name': 'COCO_train2014_000000361431.jpg',
#   'height': 401,
#   'id': 361431,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000099293.jpg',
#   'height': 360,
#   'id': 99293,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000263138.jpg',
#   'height': 640,
#   'id': 263138,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000558052.jpg',
#   'height': 375,
#   'id': 558052,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000525285.jpg',
#   'height': 612,
#   'id': 525285,
#   'set': 'val',
#   'width': 612},
#  {'file_name': 'COCO_train2014_000000426988.jpg',
#   'height': 426,
#   'id': 426988,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000099308.jpg',
#   'height': 426,
#   'id': 99308,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000099311.jpg',
#   'height': 428,
#   'id': 99311,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000426994.jpg',
#   'height': 375,
#   'id': 426994,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000361460.jpg',
#   'height': 640,
#   'id': 361460,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000492541.jpg',
#   'height': 427,
#   'id': 492541,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000197632.jpg',
#   'height': 480,
#   'id': 197632,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000361475.jpg',
#   'height': 640,
#   'id': 361475,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000164871.jpg',
#   'height': 300,
#   'id': 164871,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000099336.jpg',
#   'height': 425,
#   'id': 99336,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000394248.jpg',
#   'height': 640,
#   'id': 394248,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000361490.jpg',
#   'height': 457,
#   'id': 361490,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000328727.jpg',
#   'height': 480,
#   'id': 328727,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000033820.jpg',
#   'height': 426,
#   'id': 33820,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000328732.jpg',
#   'height': 426,
#   'id': 328732,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000033828.jpg',
#   'height': 640,
#   'id': 33828,
#   'set': 'val',
#   'width': 359},
#  {'file_name': 'COCO_train2014_000000230436.jpg',
#   'height': 427,
#   'id': 230436,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000263208.jpg',
#   'height': 425,
#   'id': 263208,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000099372.jpg',
#   'height': 480,
#   'id': 99372,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000164910.jpg',
#   'height': 409,
#   'id': 164910,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000033841.jpg',
#   'height': 480,
#   'id': 33841,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000459826.jpg',
#   'height': 480,
#   'id': 459826,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000427060.jpg',
#   'height': 333,
#   'id': 427060,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000099388.jpg',
#   'height': 480,
#   'id': 99388,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000001085.jpg',
#   'height': 480,
#   'id': 1085,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000492606.jpg',
#   'height': 333,
#   'id': 492606,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000263231.jpg',
#   'height': 427,
#   'id': 263231,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000296002.jpg',
#   'height': 375,
#   'id': 296002,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000492610.jpg',
#   'height': 480,
#   'id': 492610,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000033861.jpg',
#   'height': 426,
#   'id': 33861,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000099405.jpg',
#   'height': 480,
#   'id': 99405,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000001102.jpg',
#   'height': 640,
#   'id': 1102,
#   'set': 'val',
#   'width': 424},
#  {'file_name': 'COCO_train2014_000000066642.jpg',
#   'height': 429,
#   'id': 66642,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000394325.jpg',
#   'height': 640,
#   'id': 394325,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000296021.jpg',
#   'height': 480,
#   'id': 296021,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000132183.jpg',
#   'height': 427,
#   'id': 132183,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000099417.jpg',
#   'height': 480,
#   'id': 99417,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000394330.jpg',
#   'height': 375,
#   'id': 394330,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000525405.jpg',
#   'height': 427,
#   'id': 525405,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000427102.jpg',
#   'height': 301,
#   'id': 427102,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000492639.jpg',
#   'height': 426,
#   'id': 492639,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000296030.jpg',
#   'height': 453,
#   'id': 296030,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000492642.jpg',
#   'height': 480,
#   'id': 492642,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000033897.jpg',
#   'height': 640,
#   'id': 33897,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000230507.jpg',
#   'height': 640,
#   'id': 230507,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000296046.jpg',
#   'height': 480,
#   'id': 296046,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000525424.jpg',
#   'height': 400,
#   'id': 525424,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000492657.jpg',
#   'height': 461,
#   'id': 492657,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000099443.jpg',
#   'height': 640,
#   'id': 99443,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000394359.jpg',
#   'height': 427,
#   'id': 394359,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000361593.jpg',
#   'height': 640,
#   'id': 361593,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000296059.jpg',
#   'height': 480,
#   'id': 296059,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000066695.jpg',
#   'height': 500,
#   'id': 66695,
#   'set': 'val',
#   'width': 333},
#  {'file_name': 'COCO_train2014_000000427154.jpg',
#   'height': 496,
#   'id': 427154,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000525462.jpg',
#   'height': 426,
#   'id': 525462,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000263320.jpg',
#   'height': 480,
#   'id': 263320,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000394393.jpg',
#   'height': 359,
#   'id': 394393,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000165018.jpg',
#   'height': 640,
#   'id': 165018,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000525467.jpg',
#   'height': 476,
#   'id': 525467,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000230559.jpg',
#   'height': 427,
#   'id': 230559,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000394404.jpg',
#   'height': 480,
#   'id': 394404,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000558248.jpg',
#   'height': 375,
#   'id': 558248,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000361643.jpg',
#   'height': 558,
#   'id': 361643,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000230572.jpg',
#   'height': 424,
#   'id': 230572,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000296108.jpg',
#   'height': 480,
#   'id': 296108,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000001204.jpg',
#   'height': 640,
#   'id': 1204,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000165046.jpg',
#   'height': 360,
#   'id': 165046,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000296128.jpg',
#   'height': 427,
#   'id': 296128,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000558276.jpg',
#   'height': 640,
#   'id': 558276,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000459975.jpg',
#   'height': 428,
#   'id': 459975,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000033992.jpg',
#   'height': 480,
#   'id': 33992,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000328906.jpg',
#   'height': 480,
#   'id': 328906,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000033998.jpg',
#   'height': 640,
#   'id': 33998,
#   'set': 'val',
#   'width': 425},
#  {'file_name': 'COCO_train2014_000000165071.jpg',
#   'height': 427,
#   'id': 165071,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000099537.jpg',
#   'height': 457,
#   'id': 99537,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000361685.jpg',
#   'height': 640,
#   'id': 361685,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000132310.jpg',
#   'height': 640,
#   'id': 132310,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000427221.jpg',
#   'height': 498,
#   'id': 427221,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000459991.jpg',
#   'height': 480,
#   'id': 459991,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000230625.jpg',
#   'height': 427,
#   'id': 230625,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000427238.jpg',
#   'height': 640,
#   'id': 427238,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000263406.jpg',
#   'height': 640,
#   'id': 263406,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000001264.jpg',
#   'height': 480,
#   'id': 1264,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000066808.jpg',
#   'height': 640,
#   'id': 66808,
#   'set': 'val',
#   'width': 426},
#  {'file_name': 'COCO_train2014_000000263418.jpg',
#   'height': 500,
#   'id': 263418,
#   'set': 'val',
#   'width': 460},
#  {'file_name': 'COCO_train2014_000000525563.jpg',
#   'height': 421,
#   'id': 525563,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000492801.jpg',
#   'height': 427,
#   'id': 492801,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000492810.jpg',
#   'height': 640,
#   'id': 492810,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000034063.jpg',
#   'height': 480,
#   'id': 34063,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000066831.jpg',
#   'height': 612,
#   'id': 66831,
#   'set': 'val',
#   'width': 612},
#  {'file_name': 'COCO_train2014_000000066839.jpg',
#   'height': 640,
#   'id': 66839,
#   'set': 'val',
#   'width': 486},
#  {'file_name': 'COCO_train2014_000000001308.jpg',
#   'height': 426,
#   'id': 1308,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000197917.jpg',
#   'height': 424,
#   'id': 197917,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000001315.jpg',
#   'height': 640,
#   'id': 1315,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000460068.jpg',
#   'height': 300,
#   'id': 460068,
#   'set': 'val',
#   'width': 400},
#  {'file_name': 'COCO_train2014_000000099623.jpg',
#   'height': 640,
#   'id': 99623,
#   'set': 'val',
#   'width': 428},
#  {'file_name': 'COCO_train2014_000000328999.jpg',
#   'height': 427,
#   'id': 328999,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000132394.jpg',
#   'height': 524,
#   'id': 132394,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000394539.jpg',
#   'height': 427,
#   'id': 394539,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000263467.jpg',
#   'height': 333,
#   'id': 263467,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000230700.jpg',
#   'height': 640,
#   'id': 230700,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000066859.jpg',
#   'height': 640,
#   'id': 66859,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000394546.jpg',
#   'height': 480,
#   'id': 394546,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000558387.jpg',
#   'height': 364,
#   'id': 558387,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000099636.jpg',
#   'height': 612,
#   'id': 99636,
#   'set': 'val',
#   'width': 612},
#  {'file_name': 'COCO_train2014_000000394547.jpg',
#   'height': 510,
#   'id': 394547,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000230708.jpg',
#   'height': 612,
#   'id': 230708,
#   'set': 'val',
#   'width': 612},
#  {'file_name': 'COCO_train2014_000000427319.jpg',
#   'height': 480,
#   'id': 427319,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000230712.jpg',
#   'height': 640,
#   'id': 230712,
#   'set': 'val',
#   'width': 639},
#  {'file_name': 'COCO_train2014_000000001332.jpg',
#   'height': 419,
#   'id': 1332,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000197950.jpg',
#   'height': 426,
#   'id': 197950,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000197951.jpg',
#   'height': 428,
#   'id': 197951,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000394560.jpg',
#   'height': 425,
#   'id': 394560,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000460100.jpg',
#   'height': 640,
#   'id': 460100,
#   'set': 'val',
#   'width': 457},
#  {'file_name': 'COCO_train2014_000000230727.jpg',
#   'height': 480,
#   'id': 230727,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000034120.jpg',
#   'height': 480,
#   'id': 34120,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000197962.jpg',
#   'height': 612,
#   'id': 197962,
#   'set': 'val',
#   'width': 612},
#  {'file_name': 'COCO_train2014_000000296267.jpg',
#   'height': 375,
#   'id': 296267,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000558412.jpg',
#   'height': 640,
#   'id': 558412,
#   'set': 'val',
#   'width': 425},
# ...
#  {'file_name': 'COCO_train2014_000000133788.jpg',
#   'height': 426,
#   'id': 133788,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000494236.jpg',
#   'height': 480,
#   'id': 494236,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000068261.jpg',
#   'height': 426,
#   'id': 68261,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000494248.jpg',
#   'height': 640,
#   'id': 494248,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000035497.jpg',
#   'height': 402,
#   'id': 35497,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000461484.jpg',
#   'height': 427,
#   'id': 461484,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000494264.jpg',
#   'height': 640,
#   'id': 494264,
#   'set': 'val',
#   'width': 424},
#  {'file_name': 'COCO_train2014_000000199354.jpg',
#   'height': 426,
#   'id': 199354,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000232123.jpg',
#   'height': 480,
#   'id': 232123,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000395964.jpg',
#   'height': 375,
#   'id': 395964,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000428736.jpg',
#   'height': 480,
#   'id': 428736,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000002755.jpg',
#   'height': 297,
#   'id': 2755,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000166598.jpg',
#   'height': 640,
#   'id': 166598,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000133831.jpg',
#   'height': 480,
#   'id': 133831,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000035529.jpg',
#   'height': 480,
#   'id': 35529,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000297680.jpg',
#   'height': 640,
#   'id': 297680,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000461521.jpg',
#   'height': 480,
#   'id': 461521,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000461524.jpg',
#   'height': 500,
#   'id': 461524,
#   'set': 'val',
#   'width': 460},
#  {'file_name': 'COCO_train2014_000000559830.jpg',
#   'height': 427,
#   'id': 559830,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000101079.jpg',
#   'height': 640,
#   'id': 101079,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000330472.jpg',
#   'height': 427,
#   'id': 330472,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000461545.jpg',
#   'height': 640,
#   'id': 461545,
#   'set': 'val',
#   'width': 426},
#  {'file_name': 'COCO_train2014_000000264936.jpg',
#   'height': 426,
#   'id': 264936,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000363247.jpg',
#   'height': 480,
#   'id': 363247,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000133874.jpg',
#   'height': 426,
#   'id': 133874,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000461557.jpg',
#   'height': 640,
#   'id': 461557,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000199413.jpg',
#   'height': 427,
#   'id': 199413,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000330487.jpg',
#   'height': 640,
#   'id': 330487,
#   'set': 'val',
#   'width': 426},
#  {'file_name': 'COCO_train2014_000000461560.jpg',
#   'height': 428,
#   'id': 461560,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000133885.jpg',
#   'height': 375,
#   'id': 133885,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000035589.jpg',
#   'height': 427,
#   'id': 35589,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000494346.jpg',
#   'height': 480,
#   'id': 494346,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000101132.jpg',
#   'height': 612,
#   'id': 101132,
#   'set': 'val',
#   'width': 612},
#  {'file_name': 'COCO_train2014_000000494351.jpg',
#   'height': 332,
#   'id': 494351,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000068367.jpg',
#   'height': 427,
#   'id': 68367,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000461600.jpg',
#   'height': 480,
#   'id': 461600,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000297765.jpg',
#   'height': 375,
#   'id': 297765,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000232230.jpg',
#   'height': 512,
#   'id': 232230,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000232231.jpg',
#   'height': 480,
#   'id': 232231,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000461609.jpg',
#   'height': 500,
#   'id': 461609,
#   'set': 'val',
#   'width': 332},
#  {'file_name': 'COCO_train2014_000000396073.jpg',
#   'height': 334,
#   'id': 396073,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000166699.jpg',
#   'height': 332,
#   'id': 166699,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000068397.jpg',
#   'height': 427,
#   'id': 68397,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000494382.jpg',
#   'height': 640,
#   'id': 494382,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000396082.jpg',
#   'height': 500,
#   'id': 396082,
#   'set': 'val',
#   'width': 333},
#  {'file_name': 'COCO_train2014_000000035642.jpg',
#   'height': 427,
#   'id': 35642,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000396097.jpg',
#   'height': 400,
#   'id': 396097,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000330562.jpg',
#   'height': 480,
#   'id': 330562,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000068420.jpg',
#   'height': 640,
#   'id': 68420,
#   'set': 'val',
#   'width': 426},
#  {'file_name': 'COCO_train2014_000000002892.jpg',
#   'height': 426,
#   'id': 2892,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000363341.jpg',
#   'height': 425,
#   'id': 363341,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000068430.jpg',
#   'height': 640,
#   'id': 68430,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000494415.jpg',
#   'height': 480,
#   'id': 494415,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000527181.jpg',
#   'height': 426,
#   'id': 527181,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000461644.jpg',
#   'height': 427,
#   'id': 461644,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000396116.jpg',
#   'height': 426,
#   'id': 396116,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000363353.jpg',
#   'height': 640,
#   'id': 363353,
#   'set': 'val',
#   'width': 591},
#  {'file_name': 'COCO_train2014_000000199522.jpg',
#   'height': 425,
#   'id': 199522,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000559986.jpg',
#   'height': 480,
#   'id': 559986,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000396150.jpg',
#   'height': 640,
#   'id': 396150,
#   'set': 'val',
#   'width': 426},
#  {'file_name': 'COCO_train2014_000000101243.jpg',
#   'height': 351,
#   'id': 101243,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000396159.jpg',
#   'height': 426,
#   'id': 396159,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000232322.jpg',
#   'height': 428,
#   'id': 232322,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000035715.jpg',
#   'height': 640,
#   'id': 35715,
#   'set': 'val',
#   'width': 478},
#  {'file_name': 'COCO_train2014_000000461705.jpg',
#   'height': 480,
#   'id': 461705,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000527243.jpg',
#   'height': 400,
#   'id': 527243,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000297868.jpg',
#   'height': 427,
#   'id': 297868,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000363410.jpg',
#   'height': 640,
#   'id': 363410,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000002964.jpg',
#   'height': 383,
#   'id': 2964,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000330649.jpg',
#   'height': 427,
#   'id': 330649,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000265114.jpg',
#   'height': 480,
#   'id': 265114,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000396188.jpg',
#   'height': 375,
#   'id': 396188,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000527263.jpg',
#   'height': 612,
#   'id': 527263,
#   'set': 'val',
#   'width': 612},
#  {'file_name': 'COCO_train2014_000000396193.jpg',
#   'height': 427,
#   'id': 396193,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000232358.jpg',
#   'height': 480,
#   'id': 232358,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000265128.jpg',
#   'height': 500,
#   'id': 265128,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000527277.jpg',
#   'height': 426,
#   'id': 527277,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000560047.jpg',
#   'height': 506,
#   'id': 560047,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000002992.jpg',
#   'height': 640,
#   'id': 2992,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000232371.jpg',
#   'height': 640,
#   'id': 232371,
#   'set': 'val',
#   'width': 513},
#  {'file_name': 'COCO_train2014_000000265139.jpg',
#   'height': 333,
#   'id': 265139,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000265150.jpg',
#   'height': 640,
#   'id': 265150,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000363455.jpg',
#   'height': 640,
#   'id': 363455,
#   'set': 'val',
#   'width': 478},
#  {'file_name': 'COCO_train2014_000000134078.jpg',
#   'height': 427,
#   'id': 134078,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000494531.jpg',
#   'height': 612,
#   'id': 494531,
#   'set': 'val',
#   'width': 612},
#  {'file_name': 'COCO_train2014_000000035782.jpg',
#   'height': 427,
#   'id': 35782,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000035783.jpg',
#   'height': 428,
#   'id': 35783,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000363464.jpg',
#   'height': 375,
#   'id': 363464,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000429000.jpg',
#   'height': 640,
#   'id': 429000,
#   'set': 'val',
#   'width': 425},
#  {'file_name': 'COCO_train2014_000000265167.jpg',
#   'height': 640,
#   'id': 265167,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000035796.jpg',
#   'height': 640,
#   'id': 35796,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000265173.jpg',
#   'height': 427,
#   'id': 265173,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000166871.jpg',
#   'height': 489,
#   'id': 166871,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000232410.jpg',
#   'height': 377,
#   'id': 232410,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000330719.jpg',
#   'height': 480,
#   'id': 330719,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000461794.jpg',
#   'height': 640,
#   'id': 461794,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000265187.jpg',
#   'height': 480,
#   'id': 265187,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000101355.jpg',
#   'height': 480,
#   'id': 101355,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000297967.jpg',
#   'height': 457,
#   'id': 297967,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000494579.jpg',
#   'height': 427,
#   'id': 494579,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000461815.jpg',
#   'height': 500,
#   'id': 461815,
#   'set': 'val',
#   'width': 335},
#  {'file_name': 'COCO_train2014_000000166903.jpg',
#   'height': 424,
#   'id': 166903,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000101369.jpg',
#   'height': 427,
#   'id': 101369,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000396284.jpg',
#   'height': 375,
#   'id': 396284,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000068609.jpg',
#   'height': 375,
#   'id': 68609,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000068617.jpg',
#   'height': 640,
#   'id': 68617,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000199698.jpg',
#   'height': 640,
#   'id': 199698,
#   'set': 'val',
#   'width': 427},
#  {'file_name': 'COCO_train2014_000000363549.jpg',
#   'height': 480,
#   'id': 363549,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000396321.jpg',
#   'height': 480,
#   'id': 396321,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000298017.jpg',
#   'height': 500,
#   'id': 298017,
#   'set': 'val',
#   'width': 375},
#  {'file_name': 'COCO_train2014_000000429096.jpg',
#   'height': 376,
#   'id': 429096,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000232490.jpg',
#   'height': 640,
#   'id': 232490,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000461871.jpg',
#   'height': 640,
#   'id': 461871,
#   'set': 'val',
#   'width': 480},
#  {'file_name': 'COCO_train2014_000000298031.jpg',
#   'height': 480,
#   'id': 298031,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000068657.jpg',
#   'height': 427,
#   'id': 68657,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000232500.jpg',
#   'height': 378,
#   'id': 232500,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000330806.jpg',
#   'height': 480,
#   'id': 330806,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000429111.jpg',
#   'height': 480,
#   'id': 429111,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000101435.jpg',
#   'height': 360,
#   'id': 101435,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000429119.jpg',
#   'height': 340,
#   'id': 429119,
#   'set': 'val',
#   'width': 500},
#  {'file_name': 'COCO_train2014_000000199743.jpg',
#   'height': 427,
#   'id': 199743,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000134211.jpg',
#   'height': 500,
#   'id': 134211,
#   'set': 'val',
#   'width': 375},
#  {'file_name': 'COCO_train2014_000000494660.jpg',
#   'height': 425,
#   'id': 494660,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000330824.jpg',
#   'height': 480,
#   'id': 330824,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000429131.jpg',
#   'height': 427,
#   'id': 429131,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000265292.jpg',
#   'height': 480,
#   'id': 265292,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000068685.jpg',
#   'height': 500,
#   'id': 68685,
#   'set': 'val',
#   'width': 375},
#  {'file_name': 'COCO_train2014_000000461902.jpg',
#   'height': 612,
#   'id': 461902,
#   'set': 'val',
#   'width': 612},
#  {'file_name': 'COCO_train2014_000000003157.jpg',
#   'height': 427,
#   'id': 3157,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000166997.jpg',
#   'height': 426,
#   'id': 166997,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000494678.jpg',
#   'height': 427,
#   'id': 494678,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000560217.jpg',
#   'height': 612,
#   'id': 560217,
#   'set': 'val',
#   'width': 612},
#  {'file_name': 'COCO_train2014_000000101468.jpg',
#   'height': 427,
#   'id': 101468,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000134238.jpg',
#   'height': 480,
#   'id': 134238,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000035935.jpg',
#   'height': 480,
#   'id': 35935,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000232548.jpg',
#   'height': 440,
#   'id': 232548,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000068717.jpg',
#   'height': 480,
#   'id': 68717,
#   'set': 'val',
#   'width': 640},
#  {'file_name': 'COCO_train2014_000000560238.jpg',
#   'height': 480,
#   'id': 560238,
#   'set': 'val',
#   'width': 640},
#  ...]

# %%
len(imgIds)
# Out:
# 3522

# %%
ImgIds = ct.getImgIds(imgIds=ct.train, 
                    catIds=[('legibility','legible')])

# %%
ImgIds[0]
# Out:
# 294914

# %%
ct.loadImgs(ImgIds[4])
# Out:
# [{'file_name': 'COCO_train2014_000000032778.jpg',
#   'height': 500,
#   'id': 32778,
#   'set': 'train',
#   'width': 333}]

# %%
annIds = ct.getAnnIds(ImgIds[4])

# %%
anns = ct.loadAnns(annIds)

# %%
anns
# Out:
# [{'area': 728,
#   'bbox': [164, 478, 56, 13],
#   'class': 'machine printed',
#   'id': 1031460,
#   'image_id': 32778,
#   'language': 'english',
#   'legibility': 'legible',
#   'polygon': [164, 478, 220, 478, 220, 491, 164, 491],
#   'utf8_string': 'bryan'},
#  {'area': 1358,
#   'bbox': [226, 478, 97, 14],
#   'class': 'machine printed',
#   'id': 1031459,
#   'image_id': 32778,
#   'language': 'english',
#   'legibility': 'legible',
#   'polygon': [226, 478, 323, 478, 323, 492, 226, 492],
#   'utf8_string': 'ELKUS.COM'}]

# %%
path = '{}{}/'.format(COCO_DATA, 'train2014')    
filename = 'COCO_train2014_000000032778.jpg'
img = Image.open(path + filename)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=333x500 at 0x7F68BF41B0B8>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
plt.figure()
plt.imshow(img)
ct.showAnns(anns)
